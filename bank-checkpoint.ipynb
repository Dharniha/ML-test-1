# %%
import pandas as pd
import statsmodels.api as sm
file=pd.read_csv("C:/Users/Dharniha V/Downloads/bank.csv")
df=pd.DataFrame(file)
df
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
df.shape
# Out:
# (41188, 21)

# %%
df.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41188.000000    41188.000000   41188.000000  41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291   5167.035911
# ...

# %%
df.dtypes
# Out:
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# y                  object
# dtype: object

# %% [markdown]
# # 1.What does the primary analysis of several categorical features reveal?

# %%
import pandas as pd
import numpy as np
import time
import gc
import warnings
warnings.filterwarnings("ignore")

from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.linear_model import SGDClassifier



import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objs as go
from tqdm import tqdm

# %%
def plt_bar(column):   # firstly we define function for plotting ba graph 
    
    temp = pd.DataFrame()  # temp AS VARIABLE 0F DATA FRAME
    temp['No_deposit'] = df[df['y'] == 'no'][column].value_counts()   
    temp['Yes_deposit'] = df[df['y'] == 'yes'][column].value_counts()
    temp.plot(kind='bar')
    plt.xlabel(f'{column}')
    plt.ylabel('Number of clients')
    plt.title('Distribution of {} and deposit'.format(column))
    plt.show();

# %%
plt_bar('job')

# %% [markdown]
# The above graph shows that distribition of job with deposit, in this adminstrator and  technician deposit as good

# %%
plot_bar('marital')

# %% [markdown]
# The above graph shows that distribition of marital with deposit, in  this persons who are married good at deposits and singles also shown better

# %%
plot_bar('education')

# %% [markdown]
# The above graph shows that distribition of education with deposit, in this persons who get university degree are good at deposits and high schools also shown better as well as others are in same level approximately

# %%
plot_bar('contact')

# %% [markdown]
# cellular  contacts are better than telephone contacts

# %%
 plot_bar('loan'), plot_bar('housing')
# Out:
# (None, None)

# %% [markdown]
# owning of houses did'nt affect deposit

# %%
import seaborn as sns
sns.heatmap(df.corr(),cmap='plasma',annot=True)
sns.set(rc = {'figure.figsize':(37,25)})

# %% [markdown]
# # Perform the following Exploratory Data Analysis tasks:a. Missing Value Analysis

# %%
df.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
#drop duplicates
df.drop_duplicates(inplace=True)

# %%
#label encoder wherever required

for i in df:
    if df[i].dtype==object:
        from sklearn.preprocessing import LabelEncoder
        label=LabelEncoder()
        df[i]=label.fit_transform(df[i])

# %%
df
# Out:
#        age  job  marital  education  default  housing  loan  contact  month  \
# 0       56    3        1          0        0        0     0        1      6
# 1       57    7        1          3        1        0     0        1      6
# 2       37    7        1          3        0        2     0        1      6
# 3       40    0        1          1        0        0     0        1      6
# 4       56    7        1          3        0        0     2        1      6
# ...    ...  ...      ...        ...      ...      ...   ...      ...    ...
# 41183   73    5        1          5        0        2     0        0      7
# 41184   46    1        1          5        0        0     0        0      7
# 41185   56    5        1          6        0        2     0        0      7
# 41186   44    9        1          5        0        0     0        0      7
# 41187   74    5        1          5        0        2     0        0      7
#
# ...

# %% [markdown]
# # c. Selecting important features based on Random Forest

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection  import train_test_split

# %%
df.y = df.y.replace({'yes':1,'no':0})
df['y']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 41183    1
# 41184    0
# 41185    0
# 41186    1
# 41187    0
# Name: y, Length: 41176, dtype: int32

# %%
x = df.drop(['y'],axis=1)
y = df['y']

# %%
X = pd.get_dummies(x)
X
# Out:
#        age  job  marital  education  default  housing  loan  contact  month  \
# 0       56    3        1          0        0        0     0        1      6
# 1       57    7        1          3        1        0     0        1      6
# 2       37    7        1          3        0        2     0        1      6
# 3       40    0        1          1        0        0     0        1      6
# 4       56    7        1          3        0        0     2        1      6
# ...    ...  ...      ...        ...      ...      ...   ...      ...    ...
# 41183   73    5        1          5        0        2     0        0      7
# 41184   46    1        1          5        0        0     0        0      7
# 41185   56    5        1          6        0        2     0        0      7
# 41186   44    9        1          5        0        0     0        0      7
# 41187   74    5        1          5        0        2     0        0      7
#
# ...

# %%
X_train,y_train,X_test,y_test = train_test_split(X,y,test_size=0.3,random_state=0)
classifier= SelectFromModel(RandomForestClassifier(n_estimators = 100))

# %%
display('check the shape of splitted train and test sets', X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# 'check the shape of splitted train and test sets'
# (28823, 20)
# (12353, 20)
# (28823,)
# (12353,)

# %%
classifier
# Out:
# SelectFromModel(estimator=RandomForestClassifier())

# %% [markdown]
# # d.Handling unbalanced data using SMOTE

# %%
from sklearn.datasets import make_classification

# %%
from collections import Counter
count = Counter(y)
print(count)
# Out:
# Counter({0: 36537, 1: 4639})

# %%
# transform the dataset
from collections import Counter
import matplotlib.pyplot as plt
import pandas as pd

# %%
pip install imbalanced-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from imblearn.over_sampling import SMOTE

oversample = SMOTE()
X, y = oversample.fit_resample(X, y)

# %%
# summarize the new class distribution
counter = Counter(y)
print(counter)
# Out:
# Counter({0: 36537, 1: 36537})

# %%
from numpy import where
X, y = make_classification(n_samples=10000, n_features=2, n_redundant=0,
 n_clusters_per_class=1, weights=[0.99], flip_y=0, random_state=1)
# scatter plot of examples by class label
for label, _ in counter.items():
    row_ix = where(y == label)[0]
    plt.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
plt.legend()
plt.show()

# %% [markdown]
# # e. Standardize the data using the anyone of the scalers provided by sklearn

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
model = LogisticRegression()

# %%
x1=df.drop(['y'],axis=1).values
y1=df['y'].values

# %%
from sklearn.preprocessing import LabelEncoder
temp= LabelEncoder()

df['y'] = temp.fit_transform(df['y'])
df
# Out:
#        age  job  marital  education  default  housing  loan  contact  month  \
# 0       56    3        1          0        0        0     0        1      6
# 1       57    7        1          3        1        0     0        1      6
# 2       37    7        1          3        0        2     0        1      6
# 3       40    0        1          1        0        0     0        1      6
# 4       56    7        1          3        0        0     2        1      6
# ...    ...  ...      ...        ...      ...      ...   ...      ...    ...
# 41183   73    5        1          5        0        2     0        0      7
# 41184   46    1        1          5        0        0     0        0      7
# 41185   56    5        1          6        0        2     0        0      7
# 41186   44    9        1          5        0        0     0        0      7
# 41187   74    5        1          5        0        2     0        0      7
#
# ...
